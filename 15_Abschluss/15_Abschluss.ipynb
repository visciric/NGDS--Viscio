# %% [markdown]
# # Abschluss

# %% [markdown]
# ## Evaluation
#
# **Positiv**
#
# - Lernzyklus
# - Jupyter Notebooks
# - Übungsaufgaben
# - Projekt
#
# **Verbesserungspotential**
#
# - Einarbeitung teilweise etwas schwierig.
# - Es bräuchte manschmal etwas mehr theoretische Grundlagen (zur Mathematik).
#   - Besser absprechen mit Mathematik-Dozenten.

# %% [markdown]
# ## Offene Fragen

# %% [markdown]
# ### Isokonturlinien (Übungsblatt SW 2)

# %% [markdown]
# **Frage:** Bei diesem Graphen ist mir nicht so klar, wie ich dies zu interpretieren habe, besser gesagt kann ich mir nichts konkretes vorstellen.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Es sind Schnitte durch die 3D-Fläche entlang konstanter $y$-Werte. Diese werden Isokonturlinien genann.

# %% [markdown]
# ### Absolute vs. relative Fehler (Einarbeitung SW 9)

# %% [markdown]
# **Frage:** Während dem  lernen ist mir öfters aufgefallen, dass man die Fehlerabschätzung auf zwei Arten durchführt. Manchmal mit $x-x_1$ und  manchmal mit $x/x_1$. Meine frage lautet: kann das sein, dass wir $x-x_1$ für die Absolute Fehlerabschätzung brauchen und $x/x_1$ für die relative Fehler Abschätzung? Des weiteren ist mir nicht ganz klar wo der unterschied genau darin liegt, und wann ich welches in Betracht ziehen soll.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - Schätzung: $\tilde{x}$
# - Wahrer Wert: $x$
# - Absoluter Fehler: $\Delta_x = \tilde{x} - x$
# - Relativer Fehler: $\delta_x = \dfrac{\Delta_x}{x}$

# %% [markdown]
# ### Spalten aus 2D Array extrahieren (Vertiefung SW 9)

# %% [markdown]
# ***Frage:*** Beim markierten Code ist mir nicht ganz klar, wieso y_euler.T  transponiert wird.
#
# ![image.png](attachment:image.png)

# %%
import numpy as np

y_euler = np.array(
    [
        #  x,   v
        [0.1, 0.2],
        [0.2, 0.15],
        [0.3, 0.05],
    ]
)

x, v = y_euler.T
x, v
# Out:
# (array([0.1, 0.2, 0.3]), array([0.2 , 0.15, 0.05]))

# %% [markdown]
# Vergleiche auch Aufgabe 2 im Übungsblatt SW 2:

# %%
ire_data = np.loadtxt("Ireland.csv", delimiter=",", skiprows=1)
year, population = ire_data.T
